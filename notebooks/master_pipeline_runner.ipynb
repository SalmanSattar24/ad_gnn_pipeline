# %% [markdown]
# # Alzheimer's Disease Therapeutic Target Discovery
# ## Unified Master Pipeline Orchestrator (Steps 1-3)
# This notebook executes the full computational pipeline from raw proteomics to stable GNN-based target identification.
#
# **V3 Research Plan Alignment:**
# - Step 1: Patient Stratification & Deconvolution
# - Step 2: Multi-Layer Network Construction
# - Step 3: GATv2 GNN Training & Stability Testing

# %%
# ==== Environment Setup (Google Colab) ====
import os
import sys

try:
    import google.colab
    IN_COLAB = True
    print("Detected Google Colab Environment.")
except ImportError:
    IN_COLAB = False
    print("Detected Local Environment.")

if IN_COLAB:
    repo_url = 'https://github.com/SalmanSattar24/ad_gnn_pipeline.git'
    if not os.path.exists('ad_gnn_pipeline'):
        # !git clone {repo_url}
    
    # Move into the directory
    if os.path.basename(os.getcwd()) != 'ad_gnn_pipeline':
        os.chdir('ad_gnn_pipeline')
    
    # Force pull to ensure latest scripts (like run_step3.py) are present
    # !git pull origin master
        
    print("Installing full dependencies (this may take 2-3 mins)...")
    # !pip install -q -r requirements.txt
    print("Setup complete. Current Directory:", os.getcwd())
else:
    print("Running locally.")
# Out:
# Detected Google Colab Environment.
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 545 bytes | 545.00 KiB/s, done.
# From https://github.com/SalmanSattar24/ad_gnn_pipeline
#  * branch            master     -> FETCH_HEAD
#    5f5d9d5..5a83af9  master     -> origin/master
# Updating 5f5d9d5..5a83af9
# Fast-forward
#  run_step1.py | 40 ++++++++++++++++++++++++----------------
#  1 file changed, 24 insertions(+), 16 deletions(-)
# Installing full dependencies (this may take 2-3 mins)...
# Setup complete. Current Directory: /content/ad_gnn_pipeline

# %%
import sys
import os
import logging

sys.path.insert(0, os.path.abspath('src'))

from run_step1 import Step1Runner
from run_step2 import Step2Runner
from run_step3 import Step3Runner

logging.basicConfig(level=logging.INFO, format='%(message)s', force=True)
TEST_MODE = False  # Set to True for a super-fast proof-of-concept run

# %%
# ==== Data Readiness Check ====
if not os.path.exists('data/processed/master_patient_table_final.csv'):
    print("Step 1 outputs not found. Initializing data generation...")
    if TEST_MODE:
        os.makedirs('data/raw', exist_ok=True)
        os.makedirs('data/processed', exist_ok=True)
        os.makedirs('results', exist_ok=True)
        print("Test environment initialized.")
else:
    print("Existing data detected. Ready to proceed.")
# Out:
# Step 1 outputs not found. Initializing data generation...

# %% [markdown]
# ### Step 1: Patient Stratification
# Computes cell-type deconvolution, pseudotime trajectory, and NMF subtyping.

# %%
runner1 = Step1Runner(test_mode=TEST_MODE)
print("Executing Step 1...")
runner1.run_all()
# Out:
#   Logging initialized: logs/step1_run_20260328_091004.log
# Logging initialized: logs/step1_run_20260328_091004.log
#
#
#
#
#
#
#   ######################################################################
# ######################################################################
#   # Step 1: Patient Stratification & Subtype Discovery
# # Step 1: Patient Stratification & Subtype Discovery
#   ######################################################################
# ######################################################################
#   NORMAL MODE: Using full dataset
# NORMAL MODE: Using full dataset
#
# ======================================================================
#
# ======================================================================
#   Checking dependencies...
# Checking dependencies...
#   ======================================================================
# ======================================================================
#     [OK] pandas
#   [OK] pandas
#     [OK] numpy
#   [OK] numpy
#     [OK] matplotlib
#   [OK] matplotlib
#     [OK] seaborn
#   [OK] seaborn
#     [OK] scipy
#   [OK] scipy
#     [OK] sklearn
#   [OK] sklearn
#     [OK] scanpy
#   [OK] scanpy
#     [OK] anndata
#   [OK] anndata
# Executing Step 1...
#     [OK] umap
#   [OK] umap
#   All dependencies satisfied.
#
# All dependencies satisfied.
#
#
# ======================================================================
#
# ======================================================================
#   Checking data availability...
# Checking data availability...
#   ======================================================================
# ======================================================================
#     Raw data directory will be created: data/raw
#   Raw data directory will be created: data/raw
#   Data availability check complete.
#
# Data availability check complete.
#
#
# ======================================================================
#
# ======================================================================
#   STEP 1/5: 1A: Data Loading & Preprocessing
# STEP 1/5: 1A: Data Loading & Preprocessing
#   ======================================================================
# ======================================================================
#   ======================================================================
# ======================================================================
#   STEP 1A: Data Loading & Preprocessing
# STEP 1A: Data Loading & Preprocessing
#   ======================================================================
# ======================================================================
# [SETUP] Generated synthetic proteomics: (180, 5000)
# [SETUP] Generated synthetic metadata: (180, 8)
#   [1/10] Loading proteomics...
# [1/10] Loading proteomics...
#   Loaded proteomics: 180 samples x 5000 proteins
#   [2/10] Loading metadata...
# [2/10] Loading metadata...
#   Loaded metadata: (180, 8)
#   [3/10] Joining data...
# [3/10] Joining data...
#   Joined on 180 common samples
#   [4/10] Computing statistics...
# [4/10] Computing statistics...
#   Diagnosis: {'Control': 104, 'AD': 76}
# Diagnosis: {'Control': 104, 'AD': 76}
#   Proteomics: 180 samples x 5000 proteins
# Proteomics: 180 samples x 5000 proteins
#   Missing values: 134701 (14.97%)
# Missing values: 134701 (14.97%)
#   [5/10] QC filtering...
# [5/10] QC filtering...
#   QC: removed 0 proteins (>50% missing)
#   [6/10] KNN imputation...
# [6/10] KNN imputation...
#   KNN imputation complete (k=5)
#   [7/10] Log2 transformation...
# [7/10] Log2 transformation...
#   Log2 transformation complete
#   [8/10] Z-score normalization...
# [8/10] Z-score normalization...
#   Z-score normalization complete
#   [9/10] Covariate regression...
# [9/10] Covariate regression...
#   Covariate regression complete (3 covariates)
#   [10/10] Saving outputs...
# [10/10] Saving outputs...
#   Saved: rosmap_proteomics_cleaned.csv ((180, 5000))
#   Saved: rosmap_metadata.csv ((180, 8))
#   Saved: qc_report.png
#   ======================================================================
# ======================================================================
#   STEP 1A COMPLETE
# STEP 1A COMPLETE
#   ======================================================================
# ======================================================================
#
# [PASS] 1A: Data Loading & Preprocessing completed in 23.0s
#
# [PASS] 1A: Data Loading & Preprocessing completed in 23.0s
#
# ======================================================================
#
# ======================================================================
#   STEP 2/5: 1B: Cell-Type Deconvolution
# STEP 2/5: 1B: Cell-Type Deconvolution
#   ======================================================================
# ======================================================================
#   ======================================================================
# ======================================================================
#   STEP 1B: Cell-Type Deconvolution
# STEP 1B: Cell-Type Deconvolution
#   ======================================================================
# ======================================================================
#   [1/5] Loading reference...
# [1/5] Loading reference...
#     Reference not found, generating synthetic...
#   Reference not found, generating synthetic...
# ... storing 'cell_type' as categorical
# ... storing 'broad.cell.type' as categorical
# ... storing 'subject_id' as categorical
#   Generated synthetic reference: (8066, 10000)
#     Loaded reference: (8066, 10000)
#   Loaded reference: (8066, 10000)
#   [2/5] Loading bulk proteomics...
# [2/5] Loading bulk proteomics...
#     Loaded bulk: (180, 5000)
#   Loaded bulk: (180, 5000)
#   [3/5] Computing reference profiles...
# [3/5] Computing reference profiles...
#   [4/5] Running NNLS deconvolution...
# [4/5] Running NNLS deconvolution...
#     Deconvolved 180 patients
#   Deconvolved 180 patients
#   [5/5] Saving outputs...
# [5/5] Saving outputs...
#   Saved: cell_type_proportions.csv ((180, 6))
#   Saved: cell_type_proportions.png
#   ======================================================================
# ======================================================================
#   STEP 1B COMPLETE
# STEP 1B COMPLETE
#   ======================================================================
# ======================================================================
#
# [PASS] 1B: Cell-Type Deconvolution completed in 6.2s
#
# [PASS] 1B: Cell-Type Deconvolution completed in 6.2s
#
# ======================================================================
#
# ======================================================================
#   STEP 3/5: 1C: Disease Pseudotime
# STEP 3/5: 1C: Disease Pseudotime
#   ======================================================================
# ======================================================================
#   ======================================================================
# ======================================================================
#   STEP 1C: Disease Pseudotime
# STEP 1C: Disease Pseudotime
#   ======================================================================
# ======================================================================
#   [1/6] Loading data...
# [1/6] Loading data...
#   Loaded proteomics: (180, 5000)
#   Loaded metadata: (180, 8)
#   Loaded proportions: (180, 6)
#   [2/6] Feature selection...
# [2/6] Feature selection...
#   Selected 500 most variable proteins
#   [3/6] PCA...
# [3/6] PCA...
#   PCA: 50 components, 50.9% variance explained
#   [4/6] UMAP...
# [4/6] UMAP...
#   UMAP computed
#   [5/6] Pseudotime computation...
# [5/6] Pseudotime computation...
#   Selected root cell: patient_010
#   Pseudotime range: 0.000 - 1.000
#   [6/6] Validation...
# [6/6] Validation...
#       mmse: rho=-0.098 (p=1.89e-01)
#     mmse: rho=-0.098 (p=1.89e-01)
#       braak: rho=0.075 (FAILED threshold=0.3)
#     braak: rho=0.075 (FAILED threshold=0.3)
#       cerad: rho=0.066 (p=3.79e-01)
#     cerad: rho=0.066 (p=3.79e-01)
#       cogdx: rho=0.131 (FAILED threshold=0.3)
#     cogdx: rho=0.131 (FAILED threshold=0.3)
#     Validation: 2/4 measures passed
#   Validation: 2/4 measures passed
#   Saving outputs...
# Saving outputs...
#   Saved: pseudotime_scores.csv
#   Saved: master_patient_table.csv ((180, 17))
#   Saved: pseudotime_umap.png
#   ======================================================================
# ======================================================================
#   STEP 1C COMPLETE
# STEP 1C COMPLETE
#   ======================================================================
# ======================================================================
#
# [PASS] 1C: Disease Pseudotime completed in 6.2s
#
# [PASS] 1C: Disease Pseudotime completed in 6.2s
#
# ======================================================================
#
# ======================================================================
#   STEP 4/5: 1D: AsymAD Resilience Def
# STEP 4/5: 1D: AsymAD Resilience Def
#   ======================================================================
# ======================================================================
# ======================================================================
# STEP 1C (Addition): Cognitive Resilience Inversion Analysis
# ======================================================================
# [1/3] Loaded master patient table: (180, 17)
# [2/3] Classifying patients...
#   Class Distribution:
#     - Healthy Control: 80 patients
#     - Clinical AD: 76 patients
#     - AsymAD: 24 patients
# [3/3] Saving outputs...
#   Updated and saved: master_patient_table.csv (added 'patient_class')
# ======================================================================
# STEP 1C (Addition) COMPLETE
# ======================================================================
#
# [PASS] 1D: AsymAD Resilience Def completed in 0.1s
#
# [PASS] 1D: AsymAD Resilience Def completed in 0.1s
#
# ======================================================================
#
# ======================================================================
#   STEP 5/5: 1E: NMF Consensus Clustering
# STEP 5/5: 1E: NMF Consensus Clustering
#   ======================================================================
# ======================================================================
#   ======================================================================
# ======================================================================
#   STEP 1D: NMF Consensus Clustering
# STEP 1D: NMF Consensus Clustering
#   ======================================================================
# ======================================================================
#   [1/5] Loading data...
# [1/5] Loading data...
#   Loaded 76 AD/MCI patients
#   Shifted data to non-negative (min was -3.0097)
#     Using 76 samples for clustering
#   Using 76 samples for clustering
#   [2/5] Selecting optimal k...
# [2/5] Selecting optimal k...
#     Testing k=2...
#   Testing k=2...
#   Consensus matrix computed (76x76)
#   Cophenetic correlation: 0.7881
#       Cophenetic: 0.7881, Silhouette: 0.0029, Min size: 23
#     Cophenetic: 0.7881, Silhouette: 0.0029, Min size: 23
#     Testing k=3...
#   Testing k=3...
#   Consensus matrix computed (76x76)
#   Cophenetic correlation: 0.8056
#       Cophenetic: 0.8056, Silhouette: 0.0020, Min size: 21
#     Cophenetic: 0.8056, Silhouette: 0.0020, Min size: 21
#     Testing k=4...
#   Testing k=4...
#   Consensus matrix computed (76x76)
#   Cophenetic correlation: 0.7667
#       Cophenetic: 0.7667, Silhouette: 0.0000, Min size: 1
#     Cophenetic: 0.7667, Silhouette: 0.0000, Min size: 1
#     Testing k=5...
#   Testing k=5...
#   Consensus matrix computed (76x76)
#   Cophenetic correlation: 0.7079
#       Cophenetic: 0.7079, Silhouette: -0.0007, Min size: 7
#     Cophenetic: 0.7079, Silhouette: -0.0007, Min size: 7
#     Selected k=2 (cophenetic=0.0000)
#   Selected k=2 (cophenetic=0.0000)
#   [3/5] Final clustering with k=2...
# [3/5] Final clustering with k=2...
#   Consensus matrix computed (76x76)
#   [4/5] Saving outputs...
# [4/5] Saving outputs...
#   Saved: subtype_labels.csv
#   Saved: master_patient_table_final.csv ((180, 19))
#   [5/5] Plotting results...
# [5/5] Plotting results...
#   Saved: subtype_cluster_sizes.png
#   ======================================================================
# ======================================================================
#   STEP 1D COMPLETE
# STEP 1D COMPLETE
#   ======================================================================
# ======================================================================
#
# [PASS] 1E: NMF Consensus Clustering completed in 154.9s
#
# [PASS] 1E: NMF Consensus Clustering completed in 154.9s
#
# ======================================================================
#
# ======================================================================
#   STEP 6/5: 1F: Subtype Validation
# STEP 6/5: 1F: Subtype Validation
#   ======================================================================
# ======================================================================
#   ======================================================================
# ======================================================================
#   STEP 1E: Subtype Validation and Clinical Mapping
# STEP 1E: Subtype Validation and Clinical Mapping
#   ======================================================================
# ======================================================================
#   [1/7] Loading data...
# [1/7] Loading data...
#   Loaded master table: (180, 19)
#   Subtypes: {'ST1': 53, 'ST2': 23}
#   [2/7] Preparing survival data...
# [2/7] Preparing survival data...
#   Survival data: 76 patients, 76 events
#   [3/7] Cell-type interpretation...
# [3/7] Cell-type interpretation...
#   ST1: Ex-enriched (Early) (n=53)
#   ST2: Ex-enriched (Early) (n=23)
#   [4/7] Clinical analysis...
# [4/7] Clinical analysis...
#   mmse: p=9.68e-01
#   braaksc: p=3.37e-01
#   ceradsc: p=7.73e-01
#   [5/7] Plotting Kaplan-Meier...
# [5/7] Plotting Kaplan-Meier...
#   Saved: survival_curves.png
#   [6/7] Plotting composite figure...
# [6/7] Plotting composite figure...
#   Saved: step1_main_figure.png
#   [7/7] Generating summary report...
# [7/7] Generating summary report...
#   Saved: step1_summary.txt
#   ======================================================================
# ======================================================================
#   STEP 1E COMPLETE
# STEP 1E COMPLETE
#   ======================================================================
# ======================================================================
#
# [PASS] 1F: Subtype Validation completed in 2.4s
#
# [PASS] 1F: Subtype Validation completed in 2.4s
#
#
#
#
#
#
#   ======================================================================
# ======================================================================
#   FINAL SUMMARY REPORT
# FINAL SUMMARY REPORT
#   ======================================================================
# ======================================================================
#
# Overall Status: SUCCESS
#
# Overall Status: SUCCESS
#   Total Runtime: 3.6 minutes (213s)
# Total Runtime: 3.6 minutes (213s)
#
# Step Results:
#
# Step Results:
#     Step 1A: PASS (23.0s)
#   Step 1A: PASS (23.0s)
#           -> 180 samples x 5000 proteins
#         -> 180 samples x 5000 proteins
#     Step 1B: PASS (6.2s)
#   Step 1B: PASS (6.2s)
#     Step 1C: PASS (6.2s)
#   Step 1C: PASS (6.2s)
#           -> Pseudotime range: 0.000 - 1.000
#         -> Pseudotime range: 0.000 - 1.000
#     Step 1D: PASS (0.1s)
#   Step 1D: PASS (0.1s)
#           -> AsymAD instances found: 24
#         -> AsymAD instances found: 24
#     Step 1E: PASS (154.9s)
#   Step 1E: PASS (154.9s)
#           -> k=2: ST1=53, ST2=23
#         -> k=2: ST1=53, ST2=23
#     Step 1F: PASS (2.4s)
#   Step 1F: PASS (2.4s)
#
# Outputs saved to:
#
# Outputs saved to:
#     Data: /content/ad_gnn_pipeline/data/processed/
#   Data: /content/ad_gnn_pipeline/data/processed/
#     Figures: /content/ad_gnn_pipeline/results/step1/
#   Figures: /content/ad_gnn_pipeline/results/step1/
#     Logs: /content/ad_gnn_pipeline/logs/
#   Logs: /content/ad_gnn_pipeline/logs/
#
# ======================================================================
#
# ======================================================================
#   Documentation: See README.md for running individual steps
# Documentation: See README.md for running individual steps
#   ======================================================================
#
# ======================================================================
# True

# %% [markdown]
# ### Step 2: Network Construction
# Constructs consensus networks combining WGCNA, GLASSO, and Causal Inference.

# %%
runner2 = Step2Runner(test_mode=TEST_MODE)
print("Executing Step 2...")
runner2.run_all()
# Out:
# ######################################################################
# # Step 2: Subtype-Specific Protein Network Construction
# ######################################################################
#
# ======================================================================
# [STEP 2A] 2A: WGCNA Co-expression
# ======================================================================
#
# [FAIL] 2A: WGCNA Co-expression failed after 0.0s
# Error: Required Step 1 outputs missing.
# Traceback (most recent call last):
#   File "/content/ad_gnn_pipeline/run_step2.py", line 31, in run_step
#     result = step_func(self.data_dir, self.results_dir, self.test_mode)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ad_gnn_pipeline/src/step2/step_2a_wgcna.py", line 89, in main
#     raise FileNotFoundError("Required Step 1 outputs missing.")
# FileNotFoundError: Required Step 1 outputs missing.
#
#
# Pipeline stopped due to failure in 2A: WGCNA Co-expression
# Executing Step 2...
# False

# %% [markdown]
# ### Step 3: GNN Training & Stability
# Trains GATv2 models with the 30-seed stability protocol and extracts important proteins.

# %%
runner3 = Step3Runner(test_mode=TEST_MODE)
print("Executing Step 3...")
runner3.run_all()
# Out:
# ######################################################################
# # Step 3: Subtype-Specific GNNs & Stability Testing
# ######################################################################
#
# ======================================================================
# [STEP 3A] 3A: GNN Feature Engineering
# ======================================================================
#
# [FAIL] 3A: GNN Feature Engineering failed after 0.0s
# Error: Required Step 1 outputs missing.
# Traceback (most recent call last):
#   File "/content/ad_gnn_pipeline/run_step3.py", line 29, in run_step
#     result = step_func(self.data_dir, self.results_dir, self.test_mode)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ad_gnn_pipeline/src/step3/step_3a_feature_engineering.py", line 25, in main
#     raise FileNotFoundError("Required Step 1 outputs missing.")
# FileNotFoundError: Required Step 1 outputs missing.
#
#
# Pipeline stopped due to failure in 3A: GNN Feature Engineering
# Executing Step 3...
# False

# %% [markdown]
# # Full Pipeline Completed!
# Check the `results/` directory for outputs.
