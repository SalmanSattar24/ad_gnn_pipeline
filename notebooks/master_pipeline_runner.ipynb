# %% [markdown]
# # Alzheimer's Disease Therapeutic Target Discovery
# ## Unified Master Pipeline Orchestrator (Steps 1-3)
# This notebook executes the full computational pipeline from raw proteomics to stable GNN-based target identification.
#
# **V3 Research Plan Alignment:**
# - Step 1: Patient Stratification & Deconvolution
# - Step 2: Multi-Layer Network Construction
# - Step 3: GATv2 GNN Training & Stability Testing

# %%
# ==== Environment Setup (Google Colab) ====
import os, sys

try:
    import google.colab
    IN_COLAB = True
    print("Detected Google Colab Environment.")
except ImportError:
    IN_COLAB = False
    print("Detected Local Environment.")

if IN_COLAB:
    repo_url = "https://github.com/SalmanSattar24/ad_gnn_pipeline.git"
    if not os.path.exists("ad_gnn_pipeline"):
        # !git clone {repo_url}

    if os.path.basename(os.getcwd()) != "ad_gnn_pipeline":
        os.chdir("ad_gnn_pipeline")

    # !git pull origin master
    # Clear imported modules to force a fresh import after git pull
    import sys
    for mod in list(sys.modules):
        if mod.startswith("step1") or mod.startswith("run_step") or mod.startswith("src"):
            del sys.modules[mod]


    # Bust .pyc cache so updated source files take effect immediately
    import subprocess as _sp2
    _sp2.run(["find", ".", "-name", "*.pyc", "-delete"], check=False)
    _sp2.run(["find", ".", "-name", "__pycache__", "-type", "d", "-exec", "rm", "-rf", "{}", "+"], check=False)


    # --- Lock core scientific stack BEFORE pip runs anything ---
    # Colab ships numpy/scipy/pandas/sklearn as a pre-compiled matched set.
    # Letting pip upgrade or downgrade any of them causes C-ABI crashes.
    import numpy as _np, scipy as _sp, pandas as _pd, sklearn as _sk
    _np_ver = _np.__version__
    _sp_ver = _sp.__version__
    _pd_ver = _pd.__version__
    _sk_ver = _sk.__version__
    print(f"Locking: numpy=={_np_ver}, scipy=={_sp_ver}, pandas=={_pd_ver}, scikit-learn=={_sk_ver}")

    # Install extra packages while holding the core stack fixed
    print("Installing additional dependencies (core stack is protected)...")
    import subprocess
    subprocess.run([
        sys.executable, "-m", "pip", "install", "-q",
        f"numpy=={_np_ver}", f"scipy=={_sp_ver}",
        f"pandas=={_pd_ver}", f"scikit-learn=={_sk_ver}",
        "-r", "requirements.txt",
    ], check=True)

    import numpy as np, pandas as pd
    print(f"Final: numpy={np.__version__}, pandas={pd.__version__}")
    print("Setup complete. Directory:", os.getcwd())
else:
    print("Running locally.")
# Out:
# Detected Google Colab Environment.
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 5 (delta 3), reused 5 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 5.06 KiB | 2.53 MiB/s, done.
# From https://github.com/SalmanSattar24/ad_gnn_pipeline
#  * branch            master     -> FETCH_HEAD
#    fe516f8..8e78a89  master     -> origin/master
# Updating fe516f8..8e78a89
# Fast-forward
#  notebooks/master_pipeline_runner.ipynb | 673 +++++++++++++++++++++++++++++++--
#  run_step1.py                           | 278 --------------
#  2 files changed, 632 insertions(+), 319 deletions(-)
# Locking: numpy==2.4.3, scipy==1.16.3, pandas==2.2.2, scikit-learn==1.6.1
# Installing additional dependencies (core stack is protected)...
# Final: numpy=2.4.3, pandas=2.2.2
# Setup complete. Directory: /content/ad_gnn_pipeline

# %%
import sys, os, logging

# Ensure we are in the right directory (in case of reruns)
if os.path.exists("/content/ad_gnn_pipeline"):
    os.chdir("/content/ad_gnn_pipeline")

sys.path.insert(0, os.path.abspath("src"))

from run_step1 import Step1Runner
from run_step2 import Step2Runner
from run_step3 import Step3Runner

logging.basicConfig(level=logging.INFO, format="%(message)s", force=True)
TEST_MODE = True  # Fast pipeline validation (~5 min). Set False for research runs.
print(f"Pipeline ready. TEST_MODE={TEST_MODE}")
# Out:
# Pipeline ready. TEST_MODE=True

# %%
# ==== Data Readiness Check ====
if not os.path.exists('data/processed/master_patient_table_final.csv'):
    print("Step 1 outputs not found. Initializing data generation...")
    if TEST_MODE:
        os.makedirs('data/raw', exist_ok=True)
        os.makedirs('data/processed', exist_ok=True)
        os.makedirs('results', exist_ok=True)
        print("Test environment initialized.")
else:
    print("Existing data detected. Ready to proceed.")
# Out:
# Step 1 outputs not found. Initializing data generation...
# Test environment initialized.

# %% [markdown]
# ### Step 1: Patient Stratification
# Computes cell-type deconvolution, pseudotime trajectory, and NMF subtyping.

# %%
runner1 = Step1Runner(test_mode=TEST_MODE)
print("Executing Step 1...")
runner1.run_all()
# Out:
#   Logging initialized: logs/step1_run_20260329_031523.log
#   Logging initialized: logs/step1_run_20260329_031523.log
#   Logging initialized: logs/step1_run_20260329_031523.log
#   Logging initialized: logs/step1_run_20260329_031523.log
# Logging initialized: logs/step1_run_20260329_031523.log
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   ######################################################################
#   ######################################################################
#   ######################################################################
#   ######################################################################
# ######################################################################
#   # Step 1: Patient Stratification & Subtype Discovery
#   # Step 1: Patient Stratification & Subtype Discovery
#   # Step 1: Patient Stratification & Subtype Discovery
#   # Step 1: Patient Stratification & Subtype Discovery
# # Step 1: Patient Stratification & Subtype Discovery
#   ######################################################################
#   ######################################################################
#   ######################################################################
#   ######################################################################
# ######################################################################
#   TEST MODE: Subsampling to 50 patients, 200 proteins
#   TEST MODE: Subsampling to 50 patients, 200 proteins
#   TEST MODE: Subsampling to 50 patients, 200 proteins
#   TEST MODE: Subsampling to 50 patients, 200 proteins
# TEST MODE: Subsampling to 50 patients, 200 proteins
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#   Checking dependencies...
#   Checking dependencies...
#   Checking dependencies...
#   Checking dependencies...
# Checking dependencies...
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#     [OK] pandas
#     [OK] pandas
#     [OK] pandas
#     [OK] pandas
#   [OK] pandas
#     [OK] numpy
#     [OK] numpy
#     [OK] numpy
#     [OK] numpy
#   [OK] numpy
#     [OK] matplotlib
#     [OK] matplotlib
#     [OK] matplotlib
#     [OK] matplotlib
#   [OK] matplotlib
#     [OK] seaborn
#     [OK] seaborn
#     [OK] seaborn
#     [OK] seaborn
#   [OK] seaborn
#     [OK] scipy
#     [OK] scipy
#     [OK] scipy
#     [OK] scipy
#   [OK] scipy
#     [OK] sklearn
#     [OK] sklearn
#     [OK] sklearn
#     [OK] sklearn
#   [OK] sklearn
#     [OK] scanpy
#     [OK] scanpy
#     [OK] scanpy
#     [OK] scanpy
#   [OK] scanpy
#     [OK] anndata
#     [OK] anndata
#     [OK] anndata
#     [OK] anndata
#   [OK] anndata
#     [OK] umap
#     [OK] umap
#     [OK] umap
#     [OK] umap
#   [OK] umap
#   All dependencies satisfied.
#
#   All dependencies satisfied.
#
#   All dependencies satisfied.
#
#   All dependencies satisfied.
#
# All dependencies satisfied.
#
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#   Checking data availability...
#   Checking data availability...
#   Checking data availability...
#   Checking data availability...
# Checking data availability...
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#     Found 3 files in data/raw
#     Found 3 files in data/raw
#     Found 3 files in data/raw
#     Found 3 files in data/raw
#   Found 3 files in data/raw
#   Data availability check complete.
#
#   Data availability check complete.
#
#   Data availability check complete.
#
#   Data availability check complete.
#
# Data availability check complete.
#
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#   STEP 1/5: 1A: Data Loading & Preprocessing
#   STEP 1/5: 1A: Data Loading & Preprocessing
#   STEP 1/5: 1A: Data Loading & Preprocessing
#   STEP 1/5: 1A: Data Loading & Preprocessing
# STEP 1/5: 1A: Data Loading & Preprocessing
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#   STEP 1A: Data Loading & Preprocessing
#   STEP 1A: Data Loading & Preprocessing
#   STEP 1A: Data Loading & Preprocessing
#   STEP 1A: Data Loading & Preprocessing
# STEP 1A: Data Loading & Preprocessing
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
# [SETUP] Generated synthetic proteomics: (50, 200)
# [SETUP] Generated synthetic metadata: (50, 8)
#   [1/10] Loading proteomics...
#   [1/10] Loading proteomics...
#   [1/10] Loading proteomics...
#   [1/10] Loading proteomics...
# [1/10] Loading proteomics...
#   Loaded proteomics: 50 samples x 200 proteins
#   [2/10] Loading metadata...
#   [2/10] Loading metadata...
#   [2/10] Loading metadata...
#   [2/10] Loading metadata...
# [2/10] Loading metadata...
#   Loaded metadata: (50, 8)
#   [TEST] Subsampling to 50 patients
#   [TEST] Subsampling to 50 patients
#   [TEST] Subsampling to 50 patients
#   [TEST] Subsampling to 50 patients
# [TEST] Subsampling to 50 patients
#   Subsampling to 50 patients (test mode)
#   [3/10] Joining data...
#   [3/10] Joining data...
#   [3/10] Joining data...
#   [3/10] Joining data...
# [3/10] Joining data...
#   Joined on 50 common samples
#   [4/10] Computing statistics...
#   [4/10] Computing statistics...
#   [4/10] Computing statistics...
#   [4/10] Computing statistics...
# [4/10] Computing statistics...
#   Diagnosis: {'Control': 31, 'AD': 19}
#   Diagnosis: {'Control': 31, 'AD': 19}
#   Diagnosis: {'Control': 31, 'AD': 19}
#   Diagnosis: {'Control': 31, 'AD': 19}
# Diagnosis: {'Control': 31, 'AD': 19}
#   Proteomics: 50 samples x 200 proteins
#   Proteomics: 50 samples x 200 proteins
#   Proteomics: 50 samples x 200 proteins
#   Proteomics: 50 samples x 200 proteins
# Proteomics: 50 samples x 200 proteins
#   Missing values: 1476 (14.76%)
#   Missing values: 1476 (14.76%)
#   Missing values: 1476 (14.76%)
#   Missing values: 1476 (14.76%)
# Missing values: 1476 (14.76%)
#   [5/10] QC filtering...
#   [5/10] QC filtering...
#   [5/10] QC filtering...
#   [5/10] QC filtering...
# [5/10] QC filtering...
#   QC: removed 0 proteins (>50% missing)
#   [6/10] KNN imputation...
#   [6/10] KNN imputation...
#   [6/10] KNN imputation...
#   [6/10] KNN imputation...
# [6/10] KNN imputation...
# Executing Step 1...
#   KNN imputation complete (k=5)
#   [7/10] Log2 transformation...
#   [7/10] Log2 transformation...
#   [7/10] Log2 transformation...
#   [7/10] Log2 transformation...
# [7/10] Log2 transformation...
#   Log2 transformation complete
#   [8/10] Z-score normalization...
#   [8/10] Z-score normalization...
#   [8/10] Z-score normalization...
#   [8/10] Z-score normalization...
# [8/10] Z-score normalization...
#   Z-score normalization complete
#   [9/10] Covariate regression...
#   [9/10] Covariate regression...
#   [9/10] Covariate regression...
#   [9/10] Covariate regression...
# [9/10] Covariate regression...
#   Covariate regression complete (3 covariates)
#   [10/10] Saving outputs...
#   [10/10] Saving outputs...
#   [10/10] Saving outputs...
#   [10/10] Saving outputs...
# [10/10] Saving outputs...
#   Saved: rosmap_proteomics_cleaned.csv ((50, 200))
#   Saved: rosmap_metadata.csv ((50, 8))
#   Saved: qc_report.png
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#   STEP 1A COMPLETE
#   STEP 1A COMPLETE
#   STEP 1A COMPLETE
#   STEP 1A COMPLETE
# STEP 1A COMPLETE
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#
# [PASS] 1A: Data Loading & Preprocessing completed in 1.7s
#
# [PASS] 1A: Data Loading & Preprocessing completed in 1.7s
#
# [PASS] 1A: Data Loading & Preprocessing completed in 1.7s
#
# [PASS] 1A: Data Loading & Preprocessing completed in 1.7s
#
# [PASS] 1A: Data Loading & Preprocessing completed in 1.7s
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#   STEP 2/5: 1B: Cell-Type Deconvolution
#   STEP 2/5: 1B: Cell-Type Deconvolution
#   STEP 2/5: 1B: Cell-Type Deconvolution
#   STEP 2/5: 1B: Cell-Type Deconvolution
# STEP 2/5: 1B: Cell-Type Deconvolution
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#   STEP 1B: Cell-Type Deconvolution
#   STEP 1B: Cell-Type Deconvolution
#   STEP 1B: Cell-Type Deconvolution
#   STEP 1B: Cell-Type Deconvolution
# STEP 1B: Cell-Type Deconvolution
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#   [1/5] Loading reference...
#   [1/5] Loading reference...
#   [1/5] Loading reference...
#   [1/5] Loading reference...
# [1/5] Loading reference...
#     Loaded reference: (1000, 500)
#     Loaded reference: (1000, 500)
#     Loaded reference: (1000, 500)
#     Loaded reference: (1000, 500)
#   Loaded reference: (1000, 500)
#   [2/5] Loading bulk proteomics...
#   [2/5] Loading bulk proteomics...
#   [2/5] Loading bulk proteomics...
#   [2/5] Loading bulk proteomics...
# [2/5] Loading bulk proteomics...
#     Loaded bulk: (50, 200)
#     Loaded bulk: (50, 200)
#     Loaded bulk: (50, 200)
#     Loaded bulk: (50, 200)
#   Loaded bulk: (50, 200)
#   [3/5] Computing reference profiles...
#   [3/5] Computing reference profiles...
#   [3/5] Computing reference profiles...
#   [3/5] Computing reference profiles...
# [3/5] Computing reference profiles...
#   [4/5] Running NNLS deconvolution...
#   [4/5] Running NNLS deconvolution...
#   [4/5] Running NNLS deconvolution...
#   [4/5] Running NNLS deconvolution...
# [4/5] Running NNLS deconvolution...
#     Deconvolved 50 patients
#     Deconvolved 50 patients
#     Deconvolved 50 patients
#     Deconvolved 50 patients
#   Deconvolved 50 patients
#   [5/5] Saving outputs...
#   [5/5] Saving outputs...
#   [5/5] Saving outputs...
#   [5/5] Saving outputs...
# [5/5] Saving outputs...
#   Computing cell-type specific protein profiles...
#   Saved: cell_type_proportions.csv ((50, 6))
#   Saved: deconvolved_profiles.csv ((60000, 4))
#   Saved: cell_type_proportions.png
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#   STEP 1B COMPLETE
#   STEP 1B COMPLETE
#   STEP 1B COMPLETE
#   STEP 1B COMPLETE
# STEP 1B COMPLETE
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#
# [PASS] 1B: Cell-Type Deconvolution completed in 1.3s
#
# [PASS] 1B: Cell-Type Deconvolution completed in 1.3s
#
# [PASS] 1B: Cell-Type Deconvolution completed in 1.3s
#
# [PASS] 1B: Cell-Type Deconvolution completed in 1.3s
#
# [PASS] 1B: Cell-Type Deconvolution completed in 1.3s
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#   STEP 3/5: 1C: Disease Pseudotime
#   STEP 3/5: 1C: Disease Pseudotime
#   STEP 3/5: 1C: Disease Pseudotime
#   STEP 3/5: 1C: Disease Pseudotime
# STEP 3/5: 1C: Disease Pseudotime
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#   STEP 1C: Disease Pseudotime
#   STEP 1C: Disease Pseudotime
#   STEP 1C: Disease Pseudotime
#   STEP 1C: Disease Pseudotime
# STEP 1C: Disease Pseudotime
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#   [1/6] Loading data...
#   [1/6] Loading data...
#   [1/6] Loading data...
#   [1/6] Loading data...
# [1/6] Loading data...
#   Loaded proteomics: (50, 200)
#   Loaded metadata: (50, 8)
#   Loaded proportions: (50, 6)
#   [2/6] Feature selection...
#   [2/6] Feature selection...
#   [2/6] Feature selection...
#   [2/6] Feature selection...
# [2/6] Feature selection...
#   Selected 200 most variable proteins
#   [3/6] PCA...
#   [3/6] PCA...
#   [3/6] PCA...
#   [3/6] PCA...
# [3/6] PCA...
#   PCA: 49 components, 100.0% variance explained
#   [4/6] UMAP...
#   [4/6] UMAP...
#   [4/6] UMAP...
#   [4/6] UMAP...
# [4/6] UMAP...
#   UMAP computed
#   [5/6] Pseudotime computation...
#   [5/6] Pseudotime computation...
#   [5/6] Pseudotime computation...
#   [5/6] Pseudotime computation...
# [5/6] Pseudotime computation...
#   Selected root cell: patient_009
#   Pseudotime range: 0.000 - 1.000
#   [6/6] Validation...
#   [6/6] Validation...
#   [6/6] Validation...
#   [6/6] Validation...
# [6/6] Validation...
#       mmse: rho=-0.074 (p=6.07e-01)
#       mmse: rho=-0.074 (p=6.07e-01)
#       mmse: rho=-0.074 (p=6.07e-01)
#       mmse: rho=-0.074 (p=6.07e-01)
#     mmse: rho=-0.074 (p=6.07e-01)
#       braak: rho=0.075 (FAILED threshold=0.3)
#       braak: rho=0.075 (FAILED threshold=0.3)
#       braak: rho=0.075 (FAILED threshold=0.3)
#       braak: rho=0.075 (FAILED threshold=0.3)
#     braak: rho=0.075 (FAILED threshold=0.3)
#       cerad: rho=0.038 (p=7.95e-01)
#       cerad: rho=0.038 (p=7.95e-01)
#       cerad: rho=0.038 (p=7.95e-01)
#       cerad: rho=0.038 (p=7.95e-01)
#     cerad: rho=0.038 (p=7.95e-01)
#       cogdx: rho=-0.010 (FAILED threshold=0.3)
#       cogdx: rho=-0.010 (FAILED threshold=0.3)
#       cogdx: rho=-0.010 (FAILED threshold=0.3)
#       cogdx: rho=-0.010 (FAILED threshold=0.3)
#     cogdx: rho=-0.010 (FAILED threshold=0.3)
#     Validation: 2/4 measures passed
#     Validation: 2/4 measures passed
#     Validation: 2/4 measures passed
#     Validation: 2/4 measures passed
#   Validation: 2/4 measures passed
#   Saving outputs...
#   Saving outputs...
#   Saving outputs...
#   Saving outputs...
# Saving outputs...
#   Saved: pseudotime_scores.csv
#   Saved: master_patient_table.csv ((50, 17))
#   Saved: pseudotime_umap.png
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#   STEP 1C COMPLETE
#   STEP 1C COMPLETE
#   STEP 1C COMPLETE
#   STEP 1C COMPLETE
# STEP 1C COMPLETE
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#
# [PASS] 1C: Disease Pseudotime completed in 5.3s
#
# [PASS] 1C: Disease Pseudotime completed in 5.3s
#
# [PASS] 1C: Disease Pseudotime completed in 5.3s
#
# [PASS] 1C: Disease Pseudotime completed in 5.3s
#
# [PASS] 1C: Disease Pseudotime completed in 5.3s
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#   STEP 4/5: 1D: AsymAD Resilience Def
#   STEP 4/5: 1D: AsymAD Resilience Def
#   STEP 4/5: 1D: AsymAD Resilience Def
#   STEP 4/5: 1D: AsymAD Resilience Def
# STEP 4/5: 1D: AsymAD Resilience Def
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
# ======================================================================
# STEP 1C (Addition): Cognitive Resilience Inversion Analysis
# ======================================================================
# [1/3] Loaded master patient table: (50, 17)
# [2/3] Classifying patients...
#   Class Distribution:
#     - Healthy Control: 21 patients
#     - Clinical AD: 19 patients
#     - AsymAD: 10 patients
# [3/3] Saving outputs...
#   Updated and saved: master_patient_table.csv (added 'patient_class')
# ======================================================================
# STEP 1C (Addition) COMPLETE
# ======================================================================
#
# [PASS] 1D: AsymAD Resilience Def completed in 0.0s
#
# [PASS] 1D: AsymAD Resilience Def completed in 0.0s
#
# [PASS] 1D: AsymAD Resilience Def completed in 0.0s
#
# [PASS] 1D: AsymAD Resilience Def completed in 0.0s
#
# [PASS] 1D: AsymAD Resilience Def completed in 0.0s
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#   STEP 5/5: 1E: NMF Consensus Clustering
#   STEP 5/5: 1E: NMF Consensus Clustering
#   STEP 5/5: 1E: NMF Consensus Clustering
#   STEP 5/5: 1E: NMF Consensus Clustering
# STEP 5/5: 1E: NMF Consensus Clustering
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#   STEP 1D: NMF Consensus Clustering
#   STEP 1D: NMF Consensus Clustering
#   STEP 1D: NMF Consensus Clustering
#   STEP 1D: NMF Consensus Clustering
# STEP 1D: NMF Consensus Clustering
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#   [1/5] Loading data...
#   [1/5] Loading data...
#   [1/5] Loading data...
#   [1/5] Loading data...
# [1/5] Loading data...
#   Loaded 19 AD/MCI patients
#   Shifted data to non-negative (min was -2.9242)
#     Using 19 samples for clustering
#     Using 19 samples for clustering
#     Using 19 samples for clustering
#     Using 19 samples for clustering
#   Using 19 samples for clustering
#   [2/5] Selecting optimal k...
#   [2/5] Selecting optimal k...
#   [2/5] Selecting optimal k...
#   [2/5] Selecting optimal k...
# [2/5] Selecting optimal k...
#     Testing k=2...
#     Testing k=2...
#     Testing k=2...
#     Testing k=2...
#   Testing k=2...
#   Consensus matrix computed (19x19)
#   Cophenetic correlation: 0.9665
#       Cophenetic: 0.9665, Silhouette: 0.0282, Min size: 8
#       Cophenetic: 0.9665, Silhouette: 0.0282, Min size: 8
#       Cophenetic: 0.9665, Silhouette: 0.0282, Min size: 8
#       Cophenetic: 0.9665, Silhouette: 0.0282, Min size: 8
#     Cophenetic: 0.9665, Silhouette: 0.0282, Min size: 8
#     Testing k=3...
#     Testing k=3...
#     Testing k=3...
#     Testing k=3...
#   Testing k=3...
#   Consensus matrix computed (19x19)
#   Cophenetic correlation: 0.8405
#       Cophenetic: 0.8405, Silhouette: 0.0000, Min size: 1
#       Cophenetic: 0.8405, Silhouette: 0.0000, Min size: 1
#       Cophenetic: 0.8405, Silhouette: 0.0000, Min size: 1
#       Cophenetic: 0.8405, Silhouette: 0.0000, Min size: 1
#     Cophenetic: 0.8405, Silhouette: 0.0000, Min size: 1
#     Selected k=2 (cophenetic=0.0000)
#     Selected k=2 (cophenetic=0.0000)
#     Selected k=2 (cophenetic=0.0000)
#     Selected k=2 (cophenetic=0.0000)
#   Selected k=2 (cophenetic=0.0000)
#   [3/5] Final clustering with k=2...
#   [3/5] Final clustering with k=2...
#   [3/5] Final clustering with k=2...
#   [3/5] Final clustering with k=2...
# [3/5] Final clustering with k=2...
#   Consensus matrix computed (19x19)
#   [4/5] Saving outputs...
#   [4/5] Saving outputs...
#   [4/5] Saving outputs...
#   [4/5] Saving outputs...
# [4/5] Saving outputs...
#   Saved: subtype_labels.csv
#   Saved: master_patient_table_final.csv ((50, 19))
#   [5/5] Plotting results...
#   [5/5] Plotting results...
#   [5/5] Plotting results...
#   [5/5] Plotting results...
# [5/5] Plotting results...
#   Saved: subtype_cluster_sizes.png
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#   STEP 1D COMPLETE
#   STEP 1D COMPLETE
#   STEP 1D COMPLETE
#   STEP 1D COMPLETE
# STEP 1D COMPLETE
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#
# [PASS] 1E: NMF Consensus Clustering completed in 2.7s
#
# [PASS] 1E: NMF Consensus Clustering completed in 2.7s
#
# [PASS] 1E: NMF Consensus Clustering completed in 2.7s
#
# [PASS] 1E: NMF Consensus Clustering completed in 2.7s
#
# [PASS] 1E: NMF Consensus Clustering completed in 2.7s
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#   STEP 6/5: 1F: Subtype Validation
#   STEP 6/5: 1F: Subtype Validation
#   STEP 6/5: 1F: Subtype Validation
#   STEP 6/5: 1F: Subtype Validation
# STEP 6/5: 1F: Subtype Validation
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#   STEP 1E: Subtype Validation and Clinical Mapping
#   STEP 1E: Subtype Validation and Clinical Mapping
#   STEP 1E: Subtype Validation and Clinical Mapping
#   STEP 1E: Subtype Validation and Clinical Mapping
# STEP 1E: Subtype Validation and Clinical Mapping
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#   [1/7] Loading data...
#   [1/7] Loading data...
#   [1/7] Loading data...
#   [1/7] Loading data...
# [1/7] Loading data...
#   Loaded master table: (50, 19)
#   Subtypes: {'ST1': 11, 'ST2': 8}
#   [2/7] Preparing survival data...
#   [2/7] Preparing survival data...
#   [2/7] Preparing survival data...
#   [2/7] Preparing survival data...
# [2/7] Preparing survival data...
#   Survival data: 19 patients, 19 events
#   [3/7] Cell-type interpretation...
#   [3/7] Cell-type interpretation...
#   [3/7] Cell-type interpretation...
#   [3/7] Cell-type interpretation...
# [3/7] Cell-type interpretation...
#   ST1: Mic-enriched (Intermediate) (n=11)
#   ST2: Oli-enriched (Advanced) (n=8)
#   [4/7] Clinical analysis...
#   [4/7] Clinical analysis...
#   [4/7] Clinical analysis...
#   [4/7] Clinical analysis...
# [4/7] Clinical analysis...
#   mmse: p=5.62e-01
#   braaksc: p=4.28e-01
#   ceradsc: p=5.05e-01
#   [5/7] Plotting Kaplan-Meier...
#   [5/7] Plotting Kaplan-Meier...
#   [5/7] Plotting Kaplan-Meier...
#   [5/7] Plotting Kaplan-Meier...
# [5/7] Plotting Kaplan-Meier...
#   Saved: survival_curves.png
#   [6/7] Plotting composite figure...
#   [6/7] Plotting composite figure...
#   [6/7] Plotting composite figure...
#   [6/7] Plotting composite figure...
# [6/7] Plotting composite figure...
#   Saved: step1_main_figure.png
#   [7/7] Generating summary report...
#   [7/7] Generating summary report...
#   [7/7] Generating summary report...
#   [7/7] Generating summary report...
# [7/7] Generating summary report...
#   Saved: step1_summary.txt
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#   STEP 1E COMPLETE
#   STEP 1E COMPLETE
#   STEP 1E COMPLETE
#   STEP 1E COMPLETE
# STEP 1E COMPLETE
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#
# [PASS] 1F: Subtype Validation completed in 1.9s
#
# [PASS] 1F: Subtype Validation completed in 1.9s
#
# [PASS] 1F: Subtype Validation completed in 1.9s
#
# [PASS] 1F: Subtype Validation completed in 1.9s
#
# [PASS] 1F: Subtype Validation completed in 1.9s
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#   FINAL SUMMARY REPORT
#   FINAL SUMMARY REPORT
#   FINAL SUMMARY REPORT
#   FINAL SUMMARY REPORT
# FINAL SUMMARY REPORT
#   ======================================================================
#   ======================================================================
#   ======================================================================
#   ======================================================================
# ======================================================================
#
# Overall Status: SUCCESS
#
# Overall Status: SUCCESS
#
# Overall Status: SUCCESS
#
# Overall Status: SUCCESS
#
# Overall Status: SUCCESS
#   Total Runtime: 0.2 minutes (13s)
#   Total Runtime: 0.2 minutes (13s)
#   Total Runtime: 0.2 minutes (13s)
#   Total Runtime: 0.2 minutes (13s)
# Total Runtime: 0.2 minutes (13s)
#
# Step Results:
#
# Step Results:
#
# Step Results:
#
# Step Results:
#
# Step Results:
#     Step 1A: PASS (1.7s)
#     Step 1A: PASS (1.7s)
#     Step 1A: PASS (1.7s)
#     Step 1A: PASS (1.7s)
#   Step 1A: PASS (1.7s)
#           -> 50 samples x 200 proteins
#           -> 50 samples x 200 proteins
#           -> 50 samples x 200 proteins
#           -> 50 samples x 200 proteins
#         -> 50 samples x 200 proteins
#     Step 1B: PASS (1.3s)
#     Step 1B: PASS (1.3s)
#     Step 1B: PASS (1.3s)
#     Step 1B: PASS (1.3s)
#   Step 1B: PASS (1.3s)
#     Step 1C: PASS (5.3s)
#     Step 1C: PASS (5.3s)
#     Step 1C: PASS (5.3s)
#     Step 1C: PASS (5.3s)
#   Step 1C: PASS (5.3s)
#           -> Pseudotime range: 0.000 - 1.000
#           -> Pseudotime range: 0.000 - 1.000
#           -> Pseudotime range: 0.000 - 1.000
#           -> Pseudotime range: 0.000 - 1.000
#         -> Pseudotime range: 0.000 - 1.000
#     Step 1D: PASS (0.0s)
#     Step 1D: PASS (0.0s)
#     Step 1D: PASS (0.0s)
#     Step 1D: PASS (0.0s)
#   Step 1D: PASS (0.0s)
#           -> AsymAD instances found: 10
#           -> AsymAD instances found: 10
#           -> AsymAD instances found: 10
#           -> AsymAD instances found: 10
#         -> AsymAD instances found: 10
#     Step 1E: PASS (2.7s)
#     Step 1E: PASS (2.7s)
#     Step 1E: PASS (2.7s)
#     Step 1E: PASS (2.7s)
#   Step 1E: PASS (2.7s)
#           -> k=2: ST1=11, ST2=8
#           -> k=2: ST1=11, ST2=8
#           -> k=2: ST1=11, ST2=8
#           -> k=2: ST1=11, ST2=8
#         -> k=2: ST1=11, ST2=8
#     Step 1F: PASS (1.9s)
#     Step 1F: PASS (1.9s)
#     Step 1F: PASS (1.9s)
#     Step 1F: PASS (1.9s)
#   Step 1F: PASS (1.9s)
#
# Outputs saved to:
#
# Outputs saved to:
#
# Outputs saved to:
#
# Outputs saved to:
#
# Outputs saved to:
#     Data: /content/ad_gnn_pipeline/data/processed/
#     Data: /content/ad_gnn_pipeline/data/processed/
#     Data: /content/ad_gnn_pipeline/data/processed/
#     Data: /content/ad_gnn_pipeline/data/processed/
#   Data: /content/ad_gnn_pipeline/data/processed/
#     Figures: /content/ad_gnn_pipeline/results/step1/
#     Figures: /content/ad_gnn_pipeline/results/step1/
#     Figures: /content/ad_gnn_pipeline/results/step1/
#     Figures: /content/ad_gnn_pipeline/results/step1/
#   Figures: /content/ad_gnn_pipeline/results/step1/
#     Logs: /content/ad_gnn_pipeline/logs/
#     Logs: /content/ad_gnn_pipeline/logs/
#     Logs: /content/ad_gnn_pipeline/logs/
#     Logs: /content/ad_gnn_pipeline/logs/
#   Logs: /content/ad_gnn_pipeline/logs/
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#
# ======================================================================
#   Documentation: See README.md for running individual steps
#   Documentation: See README.md for running individual steps
#   Documentation: See README.md for running individual steps
#   Documentation: See README.md for running individual steps
# Documentation: See README.md for running individual steps
#   ======================================================================
#
#   ======================================================================
#
#   ======================================================================
#
#   ======================================================================
#
# ======================================================================
# True

# %% [markdown]
# ### Step 2: Network Construction
# Constructs consensus networks combining WGCNA, GLASSO, and Causal Inference.

# %%
runner2 = Step2Runner(test_mode=TEST_MODE)
print("Executing Step 2...")
runner2.run_all()
# Out:
# ######################################################################
# # Step 2: Subtype-Specific Protein Network Construction
# ######################################################################
#
# ======================================================================
# [STEP 2A] 2A: WGCNA Co-expression
# ======================================================================
# Processing WGCNA for ST1
# Processing WGCNA for ST2
# Executing Step 2...
# [PASS] 2A: WGCNA Co-expression completed in 0.2s
#
# ======================================================================
# [STEP 2B] 2B: Graphical Lasso Partial Correlation
# ======================================================================
# Running GLASSO for ST1 | Ast (N=11, P=5)
# Using fixed lambda for TEST MODE (N=11)
# Running GLASSO for ST2 | Ast (N=8, P=5)
# Using fixed lambda for TEST MODE (N=8)
#
# [PASS] 2B: Graphical Lasso Partial Correlation completed in 0.2s
#
# ======================================================================
# [STEP 2C] 2C: GENIE3/GRNBoost2 Causal Inference
# ======================================================================
# Running Causal Inference for ST1 | Ast (P=5)
# Running GENIE3-equivalent Causal Inference ensemble on (11, 5) data...
# Running Causal Inference for ST2 | Ast (P=5)
# Running GENIE3-equivalent Causal Inference ensemble on (8, 5) data...
#
# [PASS] 2C: GENIE3/GRNBoost2 Causal Inference completed in 2.9s
#
# ======================================================================
# [STEP 2D] 2D: Consensus Network Construction
# ======================================================================
# Building Consensus Network for ST2 | ct_Ast
# Building Consensus Network for ST1 | ct_Ast
#
# [PASS] 2D: Consensus Network Construction completed in 0.1s
#
#
# ======================================================================
# FINAL SUMMARY REPORT
# ======================================================================
#
# Overall Status: SUCCESS
# Total Runtime: 0.1 minutes (3s)
# Step Results:
#   Step 2A: PASS (0.2s)
#         -> Generated graphs: 2
#   Step 2B: PASS (0.2s)
#         -> Generated graphs: 2
#   Step 2C: PASS (2.9s)
#         -> Generated graphs: 2
#   Step 2D: PASS (0.1s)
# True

# %% [markdown]
# ### Step 3: GNN Training & Stability
# Trains GATv2 models with the 30-seed stability protocol and extracts important proteins.

# %%
runner3 = Step3Runner(test_mode=TEST_MODE)
print("Executing Step 3...")
runner3.run_all()
# Out:
# ######################################################################
# # Step 3: Subtype-Specific GNNs & Stability Testing
# ######################################################################
#
# ======================================================================
# [STEP 3A] 3A: GNN Feature Engineering
# ======================================================================
# Preparing Data for ST2 | Ast
# Preparing Data for ST1 | Ast
#
# [PASS] 3A: GNN Feature Engineering completed in 0.2s
#
# ======================================================================
# [STEP 3E] 3E: GNN Training & Stability Protocol
# ======================================================================
# Using device: cuda
# Analyzing Stability for ST2_ct_Ast_pyg_data.pt
# Running Stability Seed 1/2...
# Executing Step 3...
# Running Stability Seed 2/2...
#
# [PASS] 3E: GNN Training & Stability Protocol completed in 6.3s
#
#
# ======================================================================
# STEP 3 FINAL SUMMARY REPORT
# ======================================================================
#
# Overall Status: SUCCESS
# Total Runtime: 0.1 minutes (6s)
# Step Results:
#   Step 3A: PASS (0.2s) - Feature Engineering
#   Step 3E: PASS (6.3s) - Stability Protocol
#         -> Subtypes analyzed: 1
# True

# %% [markdown]
# # Full Pipeline Completed!
# Check the `results/` directory for outputs.
