# %% [markdown]
# # Alzheimer's Disease Therapeutic Target Discovery
# ## Unified Master Pipeline Orchestrator (Steps 1-3)
# This notebook executes the full computational pipeline from raw proteomics to stable GNN-based target identification.
#
# **V3 Research Plan Alignment:**
# - Step 1: Patient Stratification & Deconvolution
# - Step 2: Multi-Layer Network Construction
# - Step 3: GATv2 GNN Training & Stability Testing

# %%
# ==== Environment Setup (Google Colab) ====
import os
import sys

try:
    import google.colab
    IN_COLAB = True
    print("Detected Google Colab Environment.")
except ImportError:
    IN_COLAB = False
    print("Detected Local Environment.")

if IN_COLAB:
    repo_url = 'https://github.com/SalmanSattar24/ad_gnn_pipeline.git'
    if not os.path.exists('ad_gnn_pipeline'):
        # !git clone {repo_url}
    
    # Move into the directory
    if os.path.basename(os.getcwd()) != 'ad_gnn_pipeline':
        os.chdir('ad_gnn_pipeline')
    
    # Force pull to ensure latest scripts (like run_step3.py) are present
    # !git pull origin master
        
    print("Installing full dependencies (this may take 2-3 mins)...")
    # !pip install -q -r requirements.txt
    print("Setup complete. Current Directory:", os.getcwd())
else:
    print("Running locally.")
# Out:
# Detected Google Colab Environment.
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 9 (delta 6), reused 9 (delta 6), pack-reused 0 (from 0)
# Unpacking objects: 100% (9/9), 7.07 KiB | 1.41 MiB/s, done.
# From https://github.com/SalmanSattar24/ad_gnn_pipeline
#  * branch            master     -> FETCH_HEAD
#    04d3892..d35d3c4  master     -> origin/master
# Updating 04d3892..d35d3c4
# Fast-forward
#  notebooks/master_pipeline_runner.ipynb | 734 +++++++++++++++++++++++++++++----
#  requirements.txt                       |   3 +-
#  src/step2/step_2b_glasso.py            |  15 +-
#  src/step2/step_2c_causal.py            |  15 +-
#  4 files changed, 679 insertions(+), 88 deletions(-)
# Installing full dependencies (this may take 2-3 mins)...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 76.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 72.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.1/284.1 kB 30.4 MB/s eta 0:00:00
#   Building wheel for PyWGCNA (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fast-array-utils 1.4 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.64.0 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.64.0 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# Setup complete. Current Directory: /content/ad_gnn_pipeline

# %%
import sys
import os
import logging

sys.path.insert(0, os.path.abspath('src'))

from run_step1 import Step1Runner
from run_step2 import Step2Runner
from run_step3 import Step3Runner

logging.basicConfig(level=logging.INFO, format='%(message)s', force=True)
TEST_MODE = False  # Set to True for a super-fast proof-of-concept run
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_10666/3091235746.py in <cell line: 0>()
#       5 sys.path.insert(0, os.path.abspath('src'))
#       6
# ----> 7 from run_step1 import Step1Runner
#       8 from run_step2 import Step2Runner
#       9 from run_step3 import Step3Runner
#
# /content/ad_gnn_pipeline/run_step1.py in <module>
#      41 # Import the main functions from each step module
#      42 # Each step has a main(data_dir, results_dir, test_mode, ...) function that handles execution
# ---> 43 from step1.step_1a_load_preprocess import main as step_1a_main
#      44 from step1.step_1b_deconvolution import main as step_1b_main
#      45 from step1.step_1c_pseudotime import main as step_1c_main
#
# /content/ad_gnn_pipeline/src/step1/step_1a_load_preprocess.py in <module>
#      45 """
#      46
# ---> 47 import pandas as pd
#      48 import numpy as np
#      49 import matplotlib.pyplot as plt
#
# /usr/local/lib/python3.12/dist-packages/pandas/__init__.py in <module>
#      35     ) from _err
#      36
# ---> 37 from pandas._config import (
#      38     get_option,
#      39     set_option,
#
# /usr/local/lib/python3.12/dist-packages/pandas/_config/__init__.py in <module>
#      18     "warn_copy_on_write",
#      19 ]
# ---> 20 from pandas._config import config
#      21 from pandas._config import dates  # pyright: ignore[reportUnusedImport]  # noqa: F401
#      22 from pandas._config.config import (
#
# /usr/local/lib/python3.12/dist-packages/pandas/_config/config.py in <module>
#      66 import warnings
#      67
# ---> 68 from pandas._typing import (
#      69     F,
#      70     T,
#
# /usr/local/lib/python3.12/dist-packages/pandas/_typing.py in <module>
#     196     int,
#     197     np.ndarray,
# --> 198     np.random.Generator,
#     199     np.random.BitGenerator,
#     200     np.random.RandomState,
#
# /usr/local/lib/python3.12/dist-packages/numpy/__init__.py in __getattr__(attr)
#
# /usr/local/lib/python3.12/dist-packages/numpy/random/__init__.py in <module>
#     178
#     179 # add these for module-freeze analysis (like PyInstaller)
# --> 180 from . import _pickle
#     181 from . import _common
#     182 from . import _bounded_integers
#
# /usr/local/lib/python3.12/dist-packages/numpy/random/_pickle.py in <module>
# ----> 1 from .mtrand import RandomState
#       2 from ._philox import Philox
#       3 from ._pcg64 import PCG64, PCG64DXSM
#       4 from ._sfc64 import SFC64
#       5
#
# numpy/random/mtrand.pyx in init numpy.random.mtrand()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
# ==== Data Readiness Check ====
if not os.path.exists('data/processed/master_patient_table_final.csv'):
    print("Step 1 outputs not found. Initializing data generation...")
    if TEST_MODE:
        os.makedirs('data/raw', exist_ok=True)
        os.makedirs('data/processed', exist_ok=True)
        os.makedirs('results', exist_ok=True)
        print("Test environment initialized.")
else:
    print("Existing data detected. Ready to proceed.")

# %% [markdown]
# ### Step 1: Patient Stratification
# Computes cell-type deconvolution, pseudotime trajectory, and NMF subtyping.

# %%
runner1 = Step1Runner(test_mode=TEST_MODE)
print("Executing Step 1...")
runner1.run_all()

# %% [markdown]
# ### Step 2: Network Construction
# Constructs consensus networks combining WGCNA, GLASSO, and Causal Inference.

# %%
runner2 = Step2Runner(test_mode=TEST_MODE)
print("Executing Step 2...")
runner2.run_all()

# %% [markdown]
# ### Step 3: GNN Training & Stability
# Trains GATv2 models with the 30-seed stability protocol and extracts important proteins.

# %%
runner3 = Step3Runner(test_mode=TEST_MODE)
print("Executing Step 3...")
runner3.run_all()

# %% [markdown]
# # Full Pipeline Completed!
# Check the `results/` directory for outputs.
